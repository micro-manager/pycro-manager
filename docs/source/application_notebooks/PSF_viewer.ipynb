# %% [markdown]
# # Streaming data from micro-manager to napari: PSF Viewer
#
# This notebook shows how to acquire data using `micromanager`, then use `pycro-manager` to stream it to `napari`.
# Buttons to start and stop data acquisition are added to the `napari` window using the `magic-gui` package. In this example, the data displayed in `napari` is resliced to get a live PSF viewer. However, reslicing is only a small example for the data analysis possible using `napari`.

# %%
# only execute first time to install all required packages
#!pip install pycromanager queue napari pyqt5 magicgui yappi

# %%
import time
import numpy as np
import queue
#import yappi # needed for benchmarking multithreaded code

# tested with napari 0.3.8
import napari
from napari.qt import thread_worker

# tested with magicgui 0.1.6, will break with 0.2.0
from magicgui import magicgui

# tested with pycromanager 0.7.6
from pycromanager import Acquisition, multi_d_acquisition_events

# open napari in an extra window
# %gui qt

# %% [markdown]
# ## define constants
# some constants for microscope parameters
# and display options
# global variables for multithreading

# %%
# data acquired on microscope or simulated?
simulate = False
# z-stage controlled through micromanager, or externally?
z_stack_external = False
# clip image to central part. Speeds up display as data size is reduced
# is used as size for simulating data
clip =[500, 500]
# um / px, for correct scaling in napari
size_um = [0.16, 0.16]
# start in um, end in um, number of slices, active slice
z_range = [0, 50, 200, 0]
# sleep time to keep software responsive
sleep_time = 0.05
# contrast limits for display
clim = [100, 300]
# color map for display
cmap = 'plasma'

# initialize global variables
# flag to break while loops
acq_running = False
# empty queue for image data and z positions
img_queue = queue.Queue()
# xyz data stack
data = np.random.rand(z_range[2], clip[0], clip[1]) * clim[1]

# if z-stage is controlled through micromanager:
# need bridge to move stage at beginning of stack
# USE WITH CAUTION: only tested with micromanager demo config
if not(simulate) and not(z_stack_external):
    from pycromanager import Bridge
    bridge = Bridge()
    #get object representing micro-manager core
    core = bridge.get_core()
    print(core)
    core.set_position(z_range[0])
# Out:
# <pycromanager.core.mmcorej_CMMCore object at 0x7f9cb50eec70>

# %% [markdown]
# ## create dummy image and and put into stack
# adds dummy image of constant brightness
# keeps track of z position
# adds image and z position to queue
# use for testing purposes without microscope
# stack of increasing brightness helps to identify glitches

# %%
def simulate_image(b, size = [128,128]):
    """ fnc to simulate an image of constant brightness.
        Keeps track of z-position in stacks, concatenates
        image data and z-position and adds to queue.
        Inputs: int b: brightness
                np.array size: # of px in image in xy.
        Global variables: img_queue to write image and z position to
                z_range to keep track of z position
        """
    global img_queue
    global z_range
    image = np.ones(size) * b
    img_queue.put([z_range[3], np.ravel(image)])
    z_range[3]= (z_range[3]+1) % z_range[2]
    #print("simulating ", z_range[3])
    
    
def simulate_data(ii, z_range):
    """ fnc to create images with constant, but increasing brightness.
        Inputs: int ii: counter to increase brightness
                int z_range: number of slices in stack"""
    for zz in range(z_range[2]):
        brightness = (ii+1) * (zz+1) / ((z_range[2]+1)) * clim[1]
        simulate_image(brightness, clip)
        time.sleep(sleep_time)
        # need sleep time especially when simulated datasize is small or this will kill CPU

# %% [markdown]
# ## image process function and pycromanager acquisition
# adds acquired image and z position to queue,
# keeps track of z position
# built pycromanager acquisition events
# acquire data and send to image_process_fn

# %%
def grab_image(image, metadata):
    """ image_process_fnc to grab image from uManager.
        Keeps track of z-position in stacks, concatenates
        image data and z-position and adds to queue.
        Inputs: array image: image from micromanager
                metadata from micromanager
        Global variables: img_queue to write image and z position to
                z_range to keep track of z position
        """
    global img_queue
    global z_range
    
    size = np.shape(image)
    image_clipped = image[(size[0]-clip[0])//2:(size[0]+clip[0])//2,
                      (size[1]-clip[1])//2:(size[1]+clip[1])//2]
    img_queue.put([z_range[3], np.ravel(image_clipped)])
    z_range[3]= (z_range[3]+1) % z_range[2]
   
    return image, metadata


def acquire_data(z_range):
    """ micro-manager data acquisition. Creates acquisition events for z-stack.
        This example: use custom events, not multi_d_acquisition because the 
        z-stage is not run from micro-manager but controlled via external DAQ."""
    with Acquisition(directory=None, name=None, 
                     show_display=True, 
                     image_process_fn = grab_image) as acq:
        events = []
        for index, z_um in enumerate(np.linspace(z_range[0], z_range[1], z_range[2])):
            evt = {"axes": {"z_ext": index}, "z_ext": z_um}
            events.append(evt)
        acq.acquire(events)
        
        
def acquire_multid(z_range):
    """ micro-manager data acquisition. Creates acquisition events for z-stack.
        This example: use multi_d_acquisition because the z-stage is run 
        from micro-manager.
        Unless hardware triggering is set up in micro-manager, this will be fairly slow:
        micro-manager does not sweep the z-stage, but acquires plane by plane. """
    with Acquisition(directory=None, name=None, 
                     show_display=False, 
                     image_process_fn = grab_image) as acq:
        events = multi_d_acquisition_events(z_start=z_range[0], z_end=z_range[1], 
                                            z_step=(z_range[1]-z_range[0])/(z_range[2]-1))
        acq.acquire(events)

# %% [markdown]
# ## napari update display
# is called whenever the thread worker checking the queue yields an image
# adds images into xyz stack and updates data

# %%
def display_napari(pos_img):
    """ Unpacks z position and reshapes image from pos_img. Writes image into correct 
        slice of data, and updates napari display.
        Called by worker thread yielding elements from queue.
        Needs to be in code before worker thread connecting to it.
        Inputs: array pos_img: queue element containing z position and raveled image data.
        Global variables: np.array data: contains image stack
            img_queue: needed only to send task_done() signal.
    """
    global data
    global img_queue
    if pos_img is None:
        return
    # read image and z position
    image = np.reshape(pos_img[1:],(clip[0], clip[1]))
    z_pos = pos_img[0]

    # write image into correct slice of data and update display
    data[z_pos] = np.squeeze(image)
    layer = viewer.layers[0]
    layer.data = data
    #print("updating ", z_pos)

    img_queue.task_done()

# %% [markdown]
# ## worker threads appending data to queue and reading from queue

# %%
@thread_worker
def append_img(img_queue):
    """ Worker thread that adds images to a list.
        Calls either micro-manager data acquisition or functions for simulating data.
        Inputs: img_queue """
    # start microscope data acquisition
    if not simulate:
        if z_stack_external:
            while acq_running:
                acquire_data(z_range)
                time.sleep(sleep_time)
        else:
            while acq_running:
                acquire_multid(z_range)
                time.sleep(sleep_time)

    # run with simulated data
    else:
        ii = 0
        while acq_running:
            simulate_data(ii, z_range)
            ii = ii + 1
            #print("appending to queue", ii)
            time.sleep(sleep_time)
            
            
@thread_worker(connect={'yielded': display_napari})
def yield_img(img_queue):
    """ Worker thread that checks whether there are elements in the 
        queue, reads them out.
        Connected to display_napari function to update display """
    global acq_running
    
    while acq_running:
        time.sleep(sleep_time)
        # get elements from queue while there is more than one element
        # playing it safe: I'm always leaving one element in the queue
        while img_queue.qsize() > 1:
            #print("reading from queue ", img_queue.qsize())
            yield img_queue.get(block = False)

    # read out last remaining elements after end of acquisition
    while img_queue.qsize() > 0:
        yield img_queue.get(block = False)
    print("acquisition done")

# %% [markdown]
# ## define functions to start and stop acquisition
# connect to gui buttons using magic_gui
# `start_acq` restarts workers, resets `acq_running` flag and resets `z_range[3]`, ie z_pos
# `stop_acq` sets `acq_running` flag to `False`, which will stop the worker threads

# %%
@magicgui(call_button="Start")
def start_acq():
    """ Called when Start button in pressed. Starts workers and resets global variables"""
    print("starting threads...")
    global acq_running
    global z_range
    if not(acq_running):
        z_range[3] = 0
        if not(simulate) and not(z_stack_external):
            print(core.get_position())
            core.set_position(z_range[0])
            time.sleep(1)
            print(core.get_position())
        acq_running = True
        # comment in when benchmarking
        #yappi.start()
        worker1 = append_img(img_queue)
        worker2 = yield_img(img_queue)
        worker1.start()
        #worker2.start() # doesn't need to be started bc yield is connected
    else:
        print("acquisition already running!")
    
    
@magicgui(call_button = "Stop")
def stop_acq():
    print("stopping threads")
    # set global acq_running to False to stop other workers
    global acq_running
    acq_running = False
    if not(simulate) and not(z_stack_external):
        print(core.get_position())
        core.stop()
        print(core.get_position())
    # comment in when benchmarking
    # yappi.stop()

# %% [markdown]
# ## "Main" function: start napari and worker threads
# (re-)opens napary viewer
# initializes view with random data
# sets scale, contrast etc and rolls view.
# add GUI buttons for start stop

# %%
# check if viewer is already open
# if yes: close and reopen

try:
    if viewer:
        viewer.close()
except:
    print("viewer already closed or never opened")
viewer = napari.Viewer(ndisplay=2)

# initialize napari viewer with stack view and random data, reslice view
scale = [(z_range[1]-z_range[0])/z_range[2], size_um[1], size_um[0]]
layer = viewer.add_image(data, 
                        name = 'uManager',
                        colormap = cmap,
                        interpolation = 'nearest',
                        blending = 'additive',
                        rendering = 'attenuated_mip',
                        scale = scale,
                        contrast_limits = clim )
viewer.dims._roll()

# set sliders to the middle of the stack for all three dimensions.
# doesn't work anymore after fixing scaling
for dd, dim in enumerate(layer.data.shape):
    viewer.dims.set_point(dd, dim*scale[2-dd]//2)

# define start stop buttons and add to napari gui
# these will break when upgrading to magicgui v0.2.0
gui_start = start_acq.Gui()
gui_stop = stop_acq.Gui()
viewer.window.add_dock_widget(gui_start)
viewer.window.add_dock_widget(gui_stop)
# Out:
# Exception ignored in: <function JavaObjectShadow.__del__ at 0x7f9cb4ca6790>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 457, in __del__
#     self._close()
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 447, in _close
#     self._socket.send(message)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 102, in send
#     self._socket.send_multipart(message_parts)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 447, in send_multipart
#     return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 769, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in: <function JavaObjectShadow.__del__ at 0x7f9cb4ca6790>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 457, in __del__
#     self._close()
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 447, in _close
#     self._socket.send(message)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 102, in send
#     self._socket.send_multipart(message_parts)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 447, in send_multipart
#     return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 769, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in: <function JavaObjectShadow.__del__ at 0x7f9cb4ca6790>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 457, in __del__
#     self._close()
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 447, in _close
#     self._socket.send(message)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 102, in send
#     self._socket.send_multipart(message_parts)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 447, in send_multipart
#     return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 769, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in: <function JavaObjectShadow.__del__ at 0x7f9cb4ca6790>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 457, in __del__
#     self._close()
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 447, in _close
#     self._socket.send(message)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 102, in send
#     self._socket.send_multipart(message_parts)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 447, in send_multipart
#     return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 769, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Exception ignored in: <function JavaObjectShadow.__del__ at 0x7f9cb4ca6790>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 457, in __del__
#     self._close()
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 447, in _close
#     self._socket.send(message)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/pycromanager/core.py", line 102, in send
#     self._socket.send_multipart(message_parts)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 447, in send_multipart
#     return self.send(msg_parts[-1], flags, copy=copy, track=track)
#   File "/opt/anaconda3/envs/pyoformats/lib/python3.8/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 769, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# viewer already closed or never opened
# starting threads...
# 0
# 0
# stopping threads
# acquisition done

# %% [markdown]
# ## Get output from yappi
# only needs to be run when benchmarking code

# %%
#only needs to be executed when yappi is used
threads = yappi.get_thread_stats()
for thread in threads:
    print(
        "Function stats for (%s) (%d)" % (thread.name, thread.id)
    )  # it is the Thread.__class__.__name__
    yappi.get_func_stats(ctx_id=thread.id).print_all()
# Out:
# Function stats for (_MainThread) (0)
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# SystemError: NULL object passed to Py_BuildValue
# Clock type: CPU
# Ordered by: totaltime, desc
#
# name                                  ncall  tsub      ttot      tavg
# ..t-8-af3e07d989d1>:1 display_napari  255    0.061164  9.212611  0.036128
# ..yers/image/image.py:299 Image.data  255    0.003209  9.013016  0.035345
# ..ase/base.py:380 Image._update_dims  255    0.009440  7.962832  0.031227
# ..ers/base/base.py:731 Image.refresh  255    0.006357  7.457126  0.029244
# ..event.py:467 EventEmitter.__call__  127..  0.044935  6.091301  0.004770
# ..:527 EventEmitter._invoke_callback  127..  0.006939  5.994742  0.004694
# ..60 VispyImageLayer._on_data_change  255    0.015204  4.954112  0.019428
# ..ispyImageLayer._transform_position  2024   0.052185  4.060790  0.002006
# ..ayer.coordinates_of_canvas_corners  757    0.100023  3.557644  0.004700
# ..ode.py:593 SubScene.node_transform  2271   0.017526  3.530115  0.001554
# ..hain.py:31 ChainTransform.__init__  2271   0.054381  3.266222  0.001438
# ..event.py:405 EventEmitter.__call__  480..  0.119697  2.884762  0.000600
# ..:469 EventEmitter._invoke_callback  275..  0.012961  2.686383  0.000974
# ...py:507 CanvasBackendDesktop.event  247    0.004388  2.661996  0.010777
# ..y:820 CanvasBackendDesktop.paintGL  247    0.003570  2.639976  0.010688
# ..1 VispyImageLayer._on_scale_change  255    0.015492  2.552958  0.010012
# ../_base.py:27 LayerList.__getitem__  969..  0.094635  2.549382  0.000263
# ..in.py:73 ChainTransform.transforms  2271   0.060392  2.200882  0.000969
# ..spyImageLayer._on_translate_change  255    0.014175  2.099294  0.008233
# ..s.py:89 TransformChain.__newlike__  2296   0.012496  1.900865  0.000828
# ..st/_model.py:26 ListModel.__init__  2296   0.044809  1.888369  0.000822
# ..yer.py:229 VispyImageLayer.on_draw  247    0.010305  1.768553  0.007160
# .._multi.py:10 LayerList.__prsitem__  969..  0.070454  1.623328  0.000167
# ../_base.py:44 LayerList.__prsitem__  969..  0.076738  1.565852  0.000162
# .._typed.py:34 LayerList.__locitem__  841..  0.060631  1.502661  0.000178
# ..74 ChainTransform._rebuild_shaders  2271   0.039194  1.476178  0.000650
# ..e/base.py:628 Image.set_view_slice  255    0.005573  1.474910  0.005784
# ..image.py:496 Image._set_view_slice  255    0.023181  1.456815  0.005713
# ../_typed.py:59 TransformChain.index  1275   0.037648  1.384219  0.001086
# ..event.py:676 EmitterGroup.__init__  2296   0.025058  1.329414  0.000579
# ..ents/event.py:719 EmitterGroup.add  2296   0.260267  1.249999  0.000544
# ..ion.py:636 FunctionChain.functions  9084   0.101454  1.217024  0.000134
# ..ms.py:97 TransformChain.simplified  1021   0.020860  1.146267  0.001123
# ..ms/chain.py:134 ChainTransform.map  2518   0.038481  1.050381  0.000417
# ..el.py:371 Viewer._on_layers_change  255    0.008736  1.015647  0.003983
# ..transforms/_util.py:85 arg_to_vec4  10072  0.137946  0.961185  0.000095
# ..e.py:741 Image._update_coordinates  511    0.009706  0.956071  0.001871
# ..e/base.py:443 Image._slice_indices  510    0.025752  0.929543  0.001823
# ../event.py:314 EventEmitter.connect  16072  0.366105  0.894464  0.000056
# ..base/base.py:805 Image.get_message  511    0.012251  0.856365  0.001676
# <decorator-gen-4>:1 STTransform.imap  7554   0.034471  0.798134  0.000106
# ..yModifierFilterSceneCanvas.on_draw  247    0.002791  0.764548  0.003095
# ..ifierFilterSceneCanvas._draw_scene  247    0.003919  0.758098  0.003069
# ..ction.py:648 FunctionChain._update  9084   0.104783  0.677419  0.000075
# ..ifierFilterSceneCanvas.draw_visual  247    0.025993  0.675660  0.002735
# ..nction.py:184 Function.__setitem__  5562   0.165557  0.624118  0.000112
# ..py/scene/visuals.py:96 Widget.draw  741    0.005459  0.604371  0.000816
# ..tion.py:620 FunctionChain.__init__  4542   0.043269  0.600821  0.000132
# ..y:127 VispyImageLayer.scale_factor  247    0.005432  0.595663  0.002412
# ..y/visuals/visual.py:431 Image.draw  247    0.003578  0.587311  0.002378
# ..ist.py:194 LayerList._extent_world  255    0.013432  0.583309  0.002287
# ..age.py:676 Image._update_thumbnail  255    0.029449  0.508861  0.001996
# ../event.py:266 EventEmitter.connect  9084   0.196785  0.500230  0.000055
# ../program.py:98 ModularProgram.draw  247    0.002847  0.468090  0.001895
# ..function__ internals>:2 atleast_2d  12862  0.081113  0.435555  0.000034
# ..als/transforms/_util.py:47 as_vec4  10327  0.072145  0.411111  0.000040
# ..form.py:67 ChainTransform.__init__  4542   0.038430  0.396519  0.000087
# ..transforms/chain.py:178 <listcomp>  2271   0.045557  0.381944  0.000168
# .._layer.py:95 VispyImageLayer.scale  255    0.007392  0.379974  0.001490
# ..hain.py:243 ChainTransform.__del__  2271   0.033414  0.350585  0.000154
# ..onents/layerlist.py:208 <listcomp>  255    0.002422  0.347398  0.001362
# ..transforms/chain.py:179 <listcomp>  2271   0.044537  0.346258  0.000152
# ..erlist.py:235 LayerList._step_size  255    0.005469  0.334248  0.001311
# ...py:391 EventEmitter._normalize_cb  18168  0.161358  0.329617  0.000018
# ..se/base.py:433 Image._extent_world  255    0.002711  0.327810  0.001286
# ..nction.py:673 FunctionChain.append  22710  0.133611  0.326135  0.000014
# ..ent.py:375 EventEmitter.disconnect  13626  0.103564  0.321724  0.000024
# ..ist/_base.py:23 ListModel.__iter__  7653   0.035692  0.320807  0.000042
# ..py:386 MatrixTransform.shader_imap  2271   0.022173  0.304682  0.000134
# ..bject.py:142 FunctionChain.changed  9084   0.041680  0.295571  0.000033
# ..ms/linear.py:146 STTransform.scale  255    0.002486  0.283609  0.001112
# ..rms/linear.py:115 STTransform.imap  7554   0.166455  0.283013  0.000037
# <__array_function__ internals>:2 any  7092   0.047283  0.282130  0.000040
# ..onents/layerlist.py:250 <listcomp>  255    0.002646  0.279523  0.001096
# ..ransform.py:149 STTransform.update  329..  0.017421  0.278220  0.000085
# ...py:452 EventEmitter._normalize_cb  16072  0.127903  0.275073  0.000017
# ...py:381 MatrixTransform.shader_map  2271   0.021316  0.270985  0.000119
# ..y/core/shape_base.py:82 atleast_2d  12862  0.132282  0.270454  0.000021
# ../linear.py:160 STTransform._set_st  255    0.005192  0.270104  0.001059
# ../function.py:164 Function.__init__  4542   0.034200  0.266462  0.000059
# ..program.py:466 ModularProgram.draw  247    0.013300  0.260876  0.001056
# ..ayers/base/base.py:334 Image.scale  255    0.001204  0.259659  0.001018
# ..kref.py:436 WeakKeyDictionary.keys  9084   0.084673  0.253891  0.000028
# ..:572 SubScene.node_path_transforms  2271   0.022670  0.246367  0.000108
# ..event.py:235 EmitterGroup.__init__  11480  0.117423  0.240145  0.000021
# ..y/core/fromnumeric.py:52 _wrapfunc  3572   0.026132  0.230015  0.000064
# ..e/fromnumeric.py:70 _wrapreduction  10409  0.101744  0.216561  0.000021
# ..s/base/base.py:523 Image.thumbnail  255    0.024803  0.216295  0.000848
# ..xt.py:160 GLContext.flush_commands  494    0.009278  0.213848  0.000433
# ..rms.py:167 ScaleTranslate.__call__  1276   0.041665  0.213615  0.000167
# ..ator-gen-6>:1 MatrixTransform.imap  2518   0.011509  0.209031  0.000083
# ..ers/function.py:334 Function.rtype  9084   0.037197  0.207484  0.000023
# ..43 ModularProgram.update_variables  247    0.056688  0.203646  0.000824
# ..b/python3.8/inspect.py:80 ismethod  34240  0.136381  0.200772  0.000006
# <__array_function__ internals>:2 pad  765    0.005893  0.198919  0.000260
# ..ders/function.py:348 Function.code  4542   0.039725  0.195751  0.000043
# ...py:1473 _array_str_implementation  511    0.003165  0.187758  0.000367
# ..function.py:309 Function.signature  18168  0.042947  0.187695  0.000010
# ..numpy/core/fromnumeric.py:2249 any  7092   0.036702  0.186689  0.000026
# ..ages/numpy/lib/arraypad.py:532 pad  765    0.029882  0.185870  0.000243
# ..ore/arrayprint.py:516 array2string  511    0.008113  0.184593  0.000361
# ..y/gloo/glir.py:569 GlirQueue.flush  494    0.002083  0.183632  0.000372
# ../glir.py:488 _GlirQueueShare.flush  494    0.005937  0.181549  0.000368
# ../gloo/glir.py:805 GlirParser.parse  741    0.009589  0.176029  0.000238
# ..gloo/glir.py:735 GlirParser._parse  2470   0.022462  0.165058  0.000067
# ../arrayprint.py:461 ndarray.wrapper  511    0.007383  0.163421  0.000320
# ..st/_typed.py:23 ListModel.__init__  2296   0.028008  0.156896  0.000068
# ..ject.py:115 FunctionChain._add_dep  22710  0.099982  0.152376  0.000007
# ..re/arrayprint.py:478 _array2string  511    0.008308  0.152014  0.000297
# ..ib/python3.8/inspect.py:72 isclass  25206  0.102039  0.149751  0.000006
# ..ing.py:58 parse_function_signature  2271   0.035159  0.144748  0.000064
# ..ayers/transforms.py:105 <listcomp>  1021   0.012498  0.140270  0.000137
# ..nction.py:481 Function._clean_code  4542   0.077013  0.138741  0.000031
# ..ene/node.py:525 SubScene.node_path  2271   0.027850  0.138511  0.000061
# ..ite-packages/vispy/util/eq.py:5 eq  5562   0.124110  0.136609  0.000025
# ../utils/list/_typed.py:28 <genexpr>  8163   0.048444  0.128888  0.000016
# ..ray_function__ internals>:2 round_  2297   0.015442  0.126626  0.000055
# ..py:175 STTransform._update_shaders  255    0.006306  0.124312  0.000487
# ../numpy/core/_asarray.py:14 asarray  6369   0.026612  0.124095  0.000019
# ..mpy/core/_asarray.py:86 asanyarray  16943  0.066396  0.112762  0.000007
# ..nction.py:699 FunctionChain.remove  4542   0.028869  0.112016  0.000025
# ..py:477 EventEmitter._prepare_event  4805   0.053862  0.109655  0.000023
# ..:209 ChainTransform._subtr_changed  765..  0.003574  0.105451  0.000138
# ..array_function__ internals>:2 clip  765    0.005458  0.105026  0.000137
# ../node.py:402 SubScene.parent_chain  4542   0.056570  0.101828  0.000022
# ..mpy/core/fromnumeric.py:39 _wrapit  766    0.010755  0.101303  0.000132
# ..ay_function__ internals>:2 reshape  255    0.003140  0.100317  0.000393
# ..ge/image.py:596 Image._load_images  255    0.003550  0.099931  0.000392
# ..py/core/fromnumeric.py:3628 round_  2297   0.010897  0.095806  0.000042
# ..ormaps/colormap.py:60 Colormap.map  255    0.003938  0.095314  0.000374
# ..ray_function__ internals>:2 nanmin  510    0.003582  0.095165  0.000187
# ..umpy/core/fromnumeric.py:2033 clip  765    0.004065  0.094577  0.000124
# ..py/core/fromnumeric.py:199 reshape  255    0.002464  0.093664  0.000367
# ..set.py:26 _IterationGuard.__exit__  9084   0.057367  0.092574  0.000010
# ..event.py:189 EventEmitter.__init__  4542   0.044769  0.091627  0.000020
# ..i/components/dims.py:169 Dims.ndim  5339   0.035052  0.089531  0.000017
# ..umpy/lib/arraypad.py:457 _as_pairs  1530   0.019973  0.088457  0.000058
# ..spy/scene/node.py:325 Image.update  765    0.010021  0.088431  0.000116
# ..mpy/lib/nanfunctions.py:228 nanmin  510    0.008169  0.088108  0.000173
# ../_base.py:82 LayerList.__locitem__  8419   0.054689  0.086950  0.000010
# ..ray_function__ internals>:2 around  2297   0.015075  0.084909  0.000037
# ..s/event.py:300 EmitterGroup.source  39290  0.084881  0.084881  0.000002
# ..function__ internals>:2 nan_to_num  510    0.003349  0.083584  0.000164
# ..r.py:111 VispyImageLayer.translate  255    0.005133  0.083269  0.000327
# ..vispy/scene/node.py:591 <listcomp>  2271   0.043453  0.080667  0.000036
# ..s/numpy/core/_methods.py:106 _clip  765    0.011558  0.080558  0.000105
# ..image.py:630 Image.on_chunk_loaded  255    0.006345  0.079102  0.000310
# ../components/dims.py:150 Dims.order  4839   0.023093  0.078606  0.000016
# ..oo/wrappers.py:180 GLContext.clear  247    0.005188  0.077545  0.000314
# ..y/lib/type_check.py:367 nan_to_num  510    0.013209  0.076921  0.000151
# ..ray_function__ internals>:2 vstack  765    0.005223  0.074811  0.000098
# ..t.py:125 FunctionChain._remove_dep  4542   0.031080  0.074410  0.000016
# ../ndimage/interpolation.py:583 zoom  255    0.013168  0.073375  0.000288
# ..s/base/base.py:702 Image.get_value  511    0.003659  0.073220  0.000143
# ..ats/lib/python3.8/re.py:198 search  2271   0.015630  0.072385  0.000032
# ..ge/image.py:309 Image._extent_data  510    0.007226  0.071459  0.000140
# ..yprint.py:409 _get_format_function  511    0.008514  0.071275  0.000139
# ..der_object.py:52 Function.__init__  9084   0.041713  0.068926  0.000008
# ..ore/arrayprint.py:709 _formatArray  511    0.002672  0.068437  0.000134
# ..mage/image.py:742 Image._get_value  511    0.012329  0.068359  0.000134
# ..s.py:212 GLContext.set_clear_color  247    0.004703  0.067769  0.000274
# ..til/frozen.py:12 Image.__setattr__  274..  0.016281  0.066937  0.000024
# ..hon3.8/abc.py:96 __instancecheck__  9949   0.041054  0.066462  0.000007
# ..py/core/arrayprint.py:718 recurser  204..  0.027033  0.065765  0.000032
# ..rms.py:162 ScaleTranslate.__init__  3572   0.035590  0.065038  0.000018
# ..nts/dims.py:260 Dims.not_displayed  2295   0.018986  0.064730  0.000028
# ..ckages/toolz/functoolz.py:605 pipe  1021   0.007843  0.063541  0.000062
# ..mats/lib/python3.8/copy.py:66 copy  5604   0.038934  0.062906  0.000011
# ..inear.py:151 STTransform.translate  9331   0.038100  0.062200  0.000007
# ..ms/linear.py:142 STTransform.scale  9331   0.038833  0.061910  0.000007
# ..ponents/dims.py:255 Dims.displayed  2544   0.018246  0.061526  0.000024
# <__array_function__ internals>:2 all  1530   0.010275  0.059291  0.000039
# ..d/image.py:536 Image._prepare_draw  247    0.001525  0.057946  0.000235
# ..umpy/core/shape_base.py:223 vstack  765    0.007975  0.057315  0.000075
# ..l.py:448 Image._configure_gl_state  247    0.001539  0.057257  0.000232
# ..py/core/arrayprint.py:365 <lambda>  511    0.002547  0.057248  0.000112
# ..olormaps/colormap.py:64 <listcomp>  255    0.004344  0.057236  0.000224
# ../image.py:492 Image._build_texture  247    0.019897  0.056421  0.000228
# ../color_array.py:384 Color.__init__  247    0.003555  0.056380  0.000228
# ..et.py:20 _IterationGuard.__enter__  9084   0.038950  0.056105  0.000006
# ..linear.py:365 MatrixTransform.imap  2518   0.017407  0.055833  0.000022
# ..ers.py:441 GlooFunctions.set_state  247    0.011417  0.055718  0.000226
# ..function__ internals>:2 atleast_1d  1531   0.010288  0.055700  0.000036
# ..orms.py:182 ScaleTranslate.compose  2042   0.020798  0.055698  0.000027
# ..ponents/dims.py:283 Dims.set_range  765    0.005181  0.055604  0.000073
# ..py/core/fromnumeric.py:3168 around  2297   0.011255  0.054838  0.000024
# ..int.py:1124 IntegerFormat.__init__  511    0.010960  0.054701  0.000107
# ..unction__ internals>:2 concatenate  3572   0.023801  0.054673  0.000015
# ..ray_function__ internals>:2 interp  1020   0.006326  0.052892  0.000052
# ..ders/function.py:325 Function.args  9084   0.035111  0.052519  0.000006
# ..:395 WeakKeyDictionary.__setitem__  22710  0.052394  0.052394  0.000002
# ..gloo/glir.py:1315 GlirProgram.draw  247    0.005497  0.051626  0.000209
# ..hods.py:72 _clip_dep_is_scalar_nan  1530   0.012727  0.050775  0.000033
# ..layers/base/base.py:547 Image.ndim  2279   0.011088  0.050455  0.000022
# ..or/color_array.py:40 _user_to_rgba  494    0.013921  0.050404  0.000102
# ..s/event.py:307 EmitterGroup.source  20664  0.048866  0.048866  0.000002
# ..spy/scene/node.py:89 Image.visible  255    0.002167  0.047037  0.000184
# ..layer_utils.py:93 convert_to_uint8  255    0.007318  0.044959  0.000176
# ..i/utils/list/_base.py:32 <genexpr>  8163   0.032583  0.044541  0.000005
# ../components/dims.py:116 Dims.point  5339   0.027324  0.044129  0.000008
# ..ray_function__ internals>:2 nanmax  255    0.001722  0.043829  0.000172
# ..s/lib/python3.8/re.py:289 _compile  2526   0.021424  0.043118  0.000017
# ..mpy/lib/nanfunctions.py:343 nanmax  255    0.003538  0.040483  0.000159
# ..y/lib/function_base.py:1289 interp  1020   0.009103  0.040430  0.000040
# .. VispyImageLayer._master_transform  2789   0.023824  0.040080  0.000014
# ..py:377 Dims._assert_axis_in_bounds  765    0.006573  0.039975  0.000052
# ..ib/python3.8/weakref.py:345 remove  18168  0.039489  0.039489  0.000002
# ..numpy/core/fromnumeric.py:2337 all  1530   0.007746  0.039047  0.000026
# ../vispy/gloo/glir.py:748 <listcomp>  1482   0.008764  0.038941  0.000026
# ..array_function__ internals>:2 ndim  1530   0.009407  0.038048  0.000025
# ..ging/__init__.py:1412 Logger.debug  6438   0.025196  0.037975  0.000006
# ..array_function__ internals>:2 amin  1021   0.006771  0.037770  0.000037
# ..ges/vispy/gloo/glir.py:406 as_enum  3458   0.021724  0.037186  0.000011
# ..ib/nanfunctions.py:68 _replace_nan  765    0.012090  0.036124  0.000047
# ..list/_typed.py:43 ListModel._check  5867   0.024300  0.035903  0.000006
# ..ray_function__ internals>:2 copyto  2805   0.017820  0.035788  0.000013
# ..ay_function__ internals>:2 squeeze  1531   0.012068  0.035589  0.000023
# .._layer.py:90 VispyImageLayer.scale  1267   0.008828  0.035536  0.000028
# ..r.py:106 VispyImageLayer.translate  1267   0.008309  0.035121  0.000028
# ..y/core/shape_base.py:24 atleast_1d  1531   0.016488  0.035005  0.000023
# ..vent.py:295 EventEmitter.callbacks  16072  0.034753  0.034753  0.000002
# ..py:538 EventEmitter._prepare_event  1277   0.016107  0.034296  0.000027
# ..ms.py:188 ScaleTranslate.set_slice  1020   0.015010  0.033585  0.000033
# ...py:290 EventEmitter.callback_refs  16072  0.033271  0.033271  0.000002
# <__array_function__ internals>:2 dot  2518   0.016080  0.033130  0.000013
# ..akref.py:471 WeakKeyDictionary.pop  4542   0.022621  0.032601  0.000007
# ../scene/node.py:355 Image.transform  14662  0.030167  0.030167  0.000002
# ..array_function__ internals>:2 amax  766    0.004958  0.029873  0.000039
# ..util/event.py:79 Event._pop_source  4805   0.019433  0.029664  0.000006
# ..akref.py:419 WeakKeyDictionary.get  4940   0.019456  0.028996  0.000006
# ..mpy/lib/arraypad.py:86 _pad_simple  765    0.017002  0.028988  0.000038
# ../scene/node.py:165 SubScene.parent  13626  0.028790  0.028790  0.000002
# ..til/event.py:76 Event._push_source  4805   0.019329  0.028391  0.000006
# ..glir.py:1270 GlirProgram._pre_draw  247    0.009236  0.028170  0.000114
# ..ls/shaders/program.py:146 <lambda>  4940   0.018542  0.028013  0.000006
# ../variable.py:153 Variable.state_id  4940   0.019211  0.027852  0.000006
# ..lir.py:1530 GlirTexture2D.set_data  247    0.006487  0.027403  0.000111
# ../texture.py:279 Texture2D.set_data  247    0.001131  0.027394  0.000111
# ...py:343 WeakKeyDictionary.__init__  9084   0.027213  0.027213  0.000003
# ..mage/image.py:261 Image._get_order  255    0.001501  0.027072  0.000106
# ..texture.py:300 Texture2D._set_data  247    0.005523  0.026263  0.000106
# ..rray_function__ internals>:2 stack  255    0.001734  0.025868  0.000101
# ..EmitterGroup.print_callback_errors  11480  0.025773  0.025773  0.000002
# ..nt.py:690 EmitterGroup.__getattr__  9184   0.025708  0.025708  0.000003
# ..ifierFilterSceneCanvas.set_current  494    0.004287  0.025706  0.000052
# ..s/dims.py:265 Dims.displayed_order  255    0.006547  0.025571  0.000100
# ..core/arrayprint.py:695 _extendLine  1533   0.014823  0.025501  0.000017
# ..py/util/event.py:51 Event.__init__  3538   0.018553  0.025226  0.000007
# ..umpy/core/fromnumeric.py:2714 amin  1021   0.005233  0.024558  0.000024
# ..olor/color_array.py:222 Color.rgba  247    0.001287  0.024362  0.000099
# ..al.py:264 Image._transform_changed  255    0.001221  0.024338  0.000095
# .._base.py:78 _atleast_2d_dispatcher  12862  0.024237  0.024237  0.000002
# ..orms.py:177 ScaleTranslate.inverse  510    0.012508  0.024071  0.000047
# ../core/fromnumeric.py:71 <dictcomp>  10409  0.023618  0.023618  0.000002
# .. KeyModifierFilterSceneCanvas.size  757    0.007205  0.023502  0.000031
# ..nction__ internals>:2 iscomplexobj  1275   0.007748  0.023468  0.000018
# ..spy/gloo/program.py:498 <listcomp>  247    0.012484  0.023340  0.000094
# ..s/shaders/parsing.py:72 <listcomp>  2271   0.014699  0.023253  0.000010
# ..gloo/glir.py:530 GlirQueue.command  2223   0.009423  0.021879  0.000010
# ..l/event.py:253 EventEmitter.source  9610   0.020574  0.020574  0.000002
# ..set.py:16 _IterationGuard.__init__  9084   0.020539  0.020539  0.000002
# ..ders/variable.py:96 Variable.value  10502  0.020447  0.020447  0.000002
# ..k/_request.py:40 ChunkKey.__init__  255    0.005573  0.020056  0.000079
# ..umpy/core/fromnumeric.py:2589 amax  766    0.004076  0.020024  0.000026
# ..numpy/core/shape_base.py:358 stack  255    0.004908  0.019984  0.000078
# ..mponents/dims.py:236 Dims.ndisplay  9150   0.019483  0.019483  0.000002
# ..umpy/core/fromnumeric.py:3075 ndim  1530   0.008339  0.019440  0.000013
# ..py:225 InverseTransform.shader_map  9084   0.018881  0.018881  0.000002
# ..vent.py:248 EventEmitter.callbacks  9084   0.018783  0.018783  0.000002
# ..ompiler.py:40 Compiler.__getitem__  9880   0.018622  0.018622  0.000002
# ../lib/arraypad.py:129 _set_pad_area  1275   0.012626  0.018449  0.000014
# ..mage/_ni_support.py:68 _get_output  255    0.003247  0.018221  0.000071
# ..WeakKeyDictionary._commit_removals  9084   0.018114  0.018114  0.000002
# ..ransform.py:98 STTransform.inverse  9084   0.018073  0.018073  0.000002
# ..y:229 InverseTransform.shader_imap  9084   0.017954  0.017954  0.000002
# ..wrappers.py:577 GlooFunctions.glir  988    0.008099  0.017950  0.000018
# ..VispyImageLayer.downsample_texture  255    0.004811  0.017703  0.000069
# ...py:243 EventEmitter.callback_refs  9084   0.017590  0.017590  0.000002
# ..eyModifierFilterSceneCanvas.update  765    0.003870  0.017542  0.000023
# ..:171 DynamicClassAttribute.__get__  2526   0.011904  0.017154  0.000007
# ..3.8/warnings.py:130 filterwarnings  255    0.005046  0.016991  0.000067
# ../components/dims.py:120 <listcomp>  5339   0.016805  0.016805  0.000003
# ...py:100 ImageSlice.on_chunk_loaded  255    0.004376  0.016766  0.000066
# ..nction__ internals>:2 broadcast_to  255    0.001777  0.016760  0.000066
# ..sBackendDesktop._vispy_set_current  494    0.003931  0.016731  0.000034
# ..ge/image.py:332 Image.level_shapes  765    0.007454  0.016689  0.000022
# ..QtLayerWidget._on_thumbnail_change  255    0.007349  0.016435  0.000064
# ..nvasBackendDesktop._vispy_get_size  757    0.007696  0.016297  0.000022
# ..spy/scene/node.py:254 Image.canvas  6821   0.015471  0.015471  0.000002
# ..y_function__ internals>:2 isposinf  510    0.003305  0.014728  0.000029
# ..fierFilterSceneCanvas.swap_buffers  247    0.001531  0.014665  0.000059
# ..oo/gl/_gl2.py:1127 glTexSubImage2D  247    0.012570  0.014589  0.000059
# ..sform.py:197 NullTransform.__del__  2271   0.009540  0.014093  0.000006
# ..y/lib/type_check.py:357 _getmaxmin  510    0.005075  0.014050  0.000028
# ..romnumeric.py:2245 _any_dispatcher  7092   0.013769  0.013769  0.000002
# ..es/numpy/core/_methods.py:41 _amin  1004   0.004299  0.013571  0.000014
# ../stride_tricks.py:141 broadcast_to  255    0.001321  0.013417  0.000053
# ..numpy/core/_dtype.py:321 _name_get  255    0.003709  0.013403  0.000053
# ..on3.8/warnings.py:165 simplefilter  510    0.003670  0.013171  0.000026
# ..BackendDesktop._vispy_swap_buffers  247    0.002769  0.013134  0.000053
# ..ear.py:139 STTransform.shader_imap  6813   0.012824  0.012824  0.000002
# ..i/components/dims.py:180 Dims.ndim  510    0.002707  0.012823  0.000025
# ..hon3.8/warnings.py:181 _add_filter  765    0.007201  0.012800  0.000017
# ..near.py:136 STTransform.shader_map  6813   0.012782  0.012782  0.000002
# ..init__.py:1677 Logger.isEnabledFor  6438   0.012779  0.012779  0.000002
# .._function__ internals>:2 ones_like  255    0.001815  0.012592  0.000049
# ..y_function__ internals>:2 isneginf  510    0.003000  0.012539  0.000025
# ..lir.py:445 _GlirQueueShare.command  2223   0.008521  0.012456  0.000006
# .._slice.py:80 ImageSlice.load_chunk  255    0.002866  0.012287  0.000048
# ..stride_tricks.py:114 _broadcast_to  255    0.005747  0.012096  0.000047
# ..y/core/fromnumeric.py:1428 squeeze  1531   0.007935  0.011943  0.000008
# ..tion.py:368 Function.template_vars  5562   0.011872  0.011872  0.000002
# ..eyModifierFilterSceneCanvas.update  247    0.001849  0.011870  0.000048
# ..lir.py:496 _GlirQueueShare._filter  494    0.007285  0.011650  0.000024
# ...py:120 Texture2D._normalize_shape  494    0.006536  0.011286  0.000023
# ..l/event.py:259 EventEmitter.source  4542   0.011053  0.011053  0.000002
# ..image/image.py:305 Image._get_ndim  255    0.002939  0.011022  0.000043
# ..ndored/image.py:283 Image.set_data  255    0.003554  0.010778  0.000042
# ..orms.py:22 ScaleTranslate.__init__  3572   0.010639  0.010639  0.000003
# ..i/components/dims.py:96 Dims.range  765    0.003055  0.010448  0.000014
# ..lib/python3.8/copy.py:128 deepcopy  247    0.003594  0.010329  0.000042
# ..ges/numpy/lib/ufunclike.py:48 func  1020   0.004571  0.010270  0.000010
# ..ay_function__ internals>:2 argsort  255    0.001991  0.010248  0.000040
# ...py:403 MatrixTransform.inv_matrix  4789   0.010240  0.010240  0.000002
# ..o/texture.py:226 Texture2D._resize  247    0.002551  0.010229  0.000041
# ../visuals/visual.py:585 Widget.draw  494    0.005887  0.010133  0.000021
# ..CanvasBackendDesktop._vispy_update  247    0.001644  0.010021  0.000041
# ..rrayprint.py:60 _make_options_dict  511    0.005349  0.009812  0.000019
# ../events/event.py:91 Event.__init__  1277   0.007208  0.009810  0.000008
# ..EventEmitter.print_callback_errors  4542   0.009708  0.009708  0.000002
# ..nts/chunk/_request.py:46 <genexpr>  1020   0.004210  0.009531  0.000009
# ..o/context.py:45 get_current_canvas  1482   0.006284  0.009470  0.000006
# ../scene/node.py:613 Widget.__repr__  741    0.006251  0.009297  0.000013
# ..ds.py:82 _clip_dep_is_byte_swapped  1530   0.006432  0.009213  0.000006
# ..in.py:51 ChainTransform.transforms  4789   0.009175  0.009175  0.000002
# ..umpy/core/numeric.py:201 ones_like  255    0.002373  0.009113  0.000036
# ..numeric.py:3164 _around_dispatcher  4594   0.009018  0.009018  0.000002
# ..y:87 _clip_dep_invoke_with_casting  765    0.009012  0.009012  0.000012
# ..rm.py:122 NullTransform.shader_map  4542   0.008671  0.008671  0.000002
# ..y:252 GlooFunctions.set_blend_func  247    0.001631  0.008356  0.000034
# ../core/shape_base.py:421 <listcomp>  255    0.002607  0.008292  0.000033
# ..pe_base.py:219 _vhstack_dispatcher  765    0.003372  0.008282  0.000011
# ..lib/type_check.py:279 iscomplexobj  1275   0.005765  0.008148  0.000006
# ..nts/event.py:119 Event._pop_source  1277   0.005307  0.008102  0.000006
# ..ts/event.py:116 Event._push_source  1277   0.005481  0.008017  0.000006
# ..e.py:307 _name_includes_bit_suffix  255    0.001634  0.007654  0.000030
# ..ges/numpy/core/numeric.py:144 ones  255    0.002313  0.007432  0.000029
# ..oader.py:93 ChunkLoader.load_chunk  255    0.001265  0.007263  0.000028
# ..core/multiarray.py:143 concatenate  3572   0.007160  0.007160  0.000002
# .._gl2.py:1334 glVertexAttribPointer  494    0.004985  0.006790  0.000014
# ..y:208 _arrays_for_stack_dispatcher  1020   0.004229  0.006491  0.000006
# ..ges/numpy/lib/ufunclike.py:22 func  1020   0.004546  0.006482  0.000006
# ..gs.py:458 catch_warnings.__enter__  765    0.004764  0.006248  0.000008
# ..py/core/fromnumeric.py:999 argsort  255    0.001512  0.006232  0.000024
# .._support.py:52 _normalize_sequence  255    0.002342  0.006212  0.000024
# ..ce.py:59 ImageSlice.set_raw_images  255    0.002265  0.006121  0.000024
# ..y/gloo/gl/_gl2.py:410 glDrawArrays  247    0.006058  0.006058  0.000025
# ..ore/numerictypes.py:360 issubdtype  255    0.002281  0.006020  0.000024
# ..22 ChunkLoader._load_synchronously  255    0.001419  0.005998  0.000024
# ../lib/arraypad.py:33 _slice_at_axis  2550   0.005823  0.005823  0.000002
# ..hon3.8/queue.py:56 Queue.task_done  255    0.002255  0.005716  0.000022
# ..ge/interpolation.py:644 <listcomp>  255    0.002520  0.005610  0.000022
# ..ngs.py:477 catch_warnings.__exit__  765    0.004143  0.005586  0.000007
# ..r.py:826 GlirParser._gl_initialize  247    0.002433  0.005532  0.000022
# ..spy/scene/node.py:82 Image.visible  2725   0.005429  0.005429  0.000002
# ..KeyModifierFilterSceneCanvas.scene  2518   0.005428  0.005428  0.000002
# ..mpy/core/multiarray.py:1043 copyto  2805   0.005411  0.005411  0.000002
# ..ts/lib/python3.8/re.py:250 compile  255    0.001142  0.005397  0.000021
# ..py/util/event.py:106 Event.blocked  2757   0.005395  0.005395  0.000002
# ..nk/_request.py:126 _index_to_tuple  765    0.003639  0.005321  0.000007
# ..es/numpy/core/_methods.py:37 _amax  494    0.002009  0.005296  0.000011
# ..._bootstrap>:1017 _handle_fromlist  510    0.003308  0.005268  0.000010
# ..hon3.8/enum.py:664 RegexFlag.value  2526   0.005250  0.005250  0.000002
# ..python3.8/contextlib.py:238 helper  255    0.001856  0.005247  0.000021
# ..i/layers/transforms.py:83 <lambda>  2295   0.005174  0.005174  0.000002
# ..yModifierFilterSceneCanvas.context  2470   0.005029  0.005029  0.000002
# ..r.py:70 ChunkLoader.create_request  255    0.001648  0.004992  0.000020
# ../glir.py:1063 GlirProgram.activate  247    0.002199  0.004866  0.000020
# ..s/numpy/core/multiarray.py:706 dot  2518   0.004854  0.004854  0.000002
# ..umpy/lib/arraypad.py:109 <genexpr>  2040   0.004795  0.004795  0.000002
# ..gloo/context.py:140 GLContext.glir  2470   0.004770  0.004770  0.000002
# ..py:130 MatrixTransform.shader_imap  2271   0.004759  0.004759  0.000002
# ..near.py:391 MatrixTransform.matrix  2271   0.004745  0.004745  0.000002
# ..o/context.py:63 set_current_canvas  494    0.003388  0.004688  0.000009
# ..est.py:93 ChunkRequest.load_chunks  255    0.002138  0.004579  0.000018
# ..lir.py:1519 GlirTexture2D.set_size  247    0.001226  0.004533  0.000018
# ..vispy/scene/node.py:590 <listcomp>  2271   0.004519  0.004519  0.000002
# ..umpy/lib/arraypad.py:120 <genexpr>  2040   0.004410  0.004410  0.000002
# ..loo/gl/__init__.py:186 check_error  494    0.002535  0.004400  0.000009
# ..ents/chunk/_utils.py:5 get_data_id  255    0.002493  0.004289  0.000017
# ..numpy/lib/arraypad.py:58 _view_roi  1275   0.004026  0.004026  0.000003
# ..pari/_qt/qt_viewer.py:204 <lambda>  255    0.001863  0.003995  0.000016
# ..int.py:1132 IntegerFormat.__call__  1533   0.003934  0.003934  0.000003
# ..ge/_image_view.py:62 ImageView.raw  510    0.002754  0.003856  0.000008
# ..vispy/gloo/gl/_gl2.py:440 glEnable  741    0.003837  0.003837  0.000005
# .._GeneratorContextManager.__enter__  255    0.001653  0.003769  0.000015
# ..y:99 ChunkRequest.transpose_chunks  255    0.002237  0.003709  0.000015
# ..umpy/core/getlimits.py:366 __new__  510    0.002597  0.003707  0.000007
# ..rs/base/base.py:373 Image.position  510    0.001557  0.003699  0.000007
# ..yers/image/image.py:294 Image.data  1275   0.003678  0.003678  0.000003
# ..s/vispy/gloo/util.py:76 check_enum  247    0.002180  0.003608  0.000015
# ..function__ internals>:2 empty_like  255    0.001765  0.003574  0.000014
# ..yers/base/base.py:573 Image.status  511    0.002207  0.003541  0.000007
# ..y/gloo/gl/_gl2.py:69 glBindTexture  988    0.003529  0.003529  0.000004
# .. _GeneratorContextManager.__exit__  255    0.001714  0.003506  0.000014
# .._request.py:110 ChunkRequest.image  510    0.002364  0.003461  0.000007
# ..p/canvas.py:776 DrawEvent.__init__  247    0.001358  0.003459  0.000014
# ..umpy/lib/ufunclike.py:127 isposinf  510    0.003443  0.003443  0.000007
# ..umeric.py:1424 _squeeze_dispatcher  1531   0.003409  0.003409  0.000002
# .. _GeneratorContextManager.__init__  255    0.002541  0.003391  0.000013
# ..equest.py:79 ChunkRequest.__init__  255    0.002237  0.003344  0.000013
# ..olor/color_array.py:396 Color.rgba  247    0.001588  0.003329  0.000013
# ..lir.py:1303 GlirProgram._post_draw  247    0.001728  0.003327  0.000013
# ..re/numerictypes.py:286 issubclass_  510    0.002164  0.003267  0.000006
# ..ispy/gloo/context.py:56 <listcomp>  1482   0.003186  0.003186  0.000002
# .._base.py:20 _atleast_1d_dispatcher  1531   0.003155  0.003155  0.000002
# ../vispy/gloo/gl/_gl2.py:166 glClear  247    0.003082  0.003082  0.000012
# ..ers/base/base.py:306 Image.visible  1021   0.002996  0.002996  0.000003
# ..romnumeric.py:2333 _all_dispatcher  1530   0.002926  0.002926  0.000002
# ..omnumeric.py:3071 _ndim_dispatcher  1530   0.002918  0.002918  0.000002
# ..i/layers/base/base.py:222 <lambda>  255    0.001148  0.002880  0.000011
# ..spy/gloo/program.py:500 <listcomp>  247    0.001834  0.002867  0.000012
# ..ngs.py:437 catch_warnings.__init__  765    0.002759  0.002759  0.000004
# ..ayers/image/image.py:758 <genexpr>  1022   0.002757  0.002757  0.000003
# ..hape_base.py:349 _stack_dispatcher  255    0.001160  0.002741  0.000011
# ../python3.8/copy.py:242 _keep_alive  247    0.001854  0.002731  0.000011
# ../arrayprint.py:358 _get_formatdict  511    0.002702  0.002702  0.000005
# ..py/gloo/gl/_gl2.py:42 glBindBuffer  741    0.002614  0.002614  0.000004
# ..thon3.8/copy.py:226 _deepcopy_dict  247    0.001671  0.002580  0.000010
# ..lir.py:1428 GlirTexture2D.activate  247    0.001356  0.002580  0.000010
# ../gloo/gl/_gl2.py:961 glPixelStorei  494    0.002556  0.002556  0.000005
# ..s/visual.py:194 MeshVisual.visible  988    0.002487  0.002487  0.000003
# ../events/event.py:146 Event.blocked  1277   0.002467  0.002467  0.000002
# ..rs/base/base.py:368 Image.position  1021   0.002416  0.002416  0.000002
# ..e_check.py:206 _is_type_dispatcher  1275   0.002367  0.002367  0.000002
# ..umpy/lib/ufunclike.py:198 isneginf  510    0.002256  0.002256  0.000004
# ../gloo/gl/_gl2.py:1290 glUseProgram  247    0.002184  0.002184  0.000009
# ..widgets/qt_dims.py:375 QtDims.stop  255    0.001511  0.002132  0.000008
# ..:115 ChunkRequest.thumbnail_source  255    0.001574  0.002110  0.000008
# ..layers/base/base.py:533 <listcomp>  255    0.002101  0.002101  0.000008
# ..mage/image.py:273 Image._data_view  255    0.001390  0.001992  0.000008
# ..esktop._vispy_get_fb_bind_location  247    0.001132  0.001979  0.000008
# ..py/lib/ufunclike.py:68 _dispatcher  1020   0.001936  0.001936  0.000002
# ..reading.py:246 Condition.__enter__  255    0.001241  0.001900  0.000007
# ..on_base.py:1285 _interp_dispatcher  1020   0.001897  0.001897  0.000002
# ..omnumeric.py:2709 _amin_dispatcher  1021   0.001880  0.001880  0.000002
# ..spy/gloo/gl/_gl2.py:639 glGetError  494    0.001865  0.001865  0.000004
# ../image/_image_utils.py:6 guess_rgb  255    0.001309  0.001854  0.000007
# ..layers/base/base.py:446 <listcomp>  510    0.001805  0.001805  0.000004
# ..ispy/gloo/gl/_gl2.py:392 glDisable  494    0.001790  0.001790  0.000004
# ..olor/color_array.py:217 Color.rgba  247    0.001030  0.001741  0.000007
# ..se/base.py:482 Image._set_editable  255    0.001177  0.001732  0.000007
# ../vispy/util/profiler.py:64 __new__  247    0.001279  0.001726  0.000007
# ..Program._process_pending_variables  247    0.001201  0.001660  0.000007
# ..y/gloo/gl/_gl2.py:175 glClearColor  247    0.001658  0.001658  0.000007
# ..re/getlimits.py:498 iinfo.__init__  255    0.001632  0.001632  0.000006
# ..vispy/scene/node.py:94 Widget.name  741    0.001627  0.001627  0.000002
# ../lib/function_base.py:244 iterable  255    0.001109  0.001604  0.000006
# ..vispy/gloo/wrappers.py:70 _to_args  247    0.001108  0.001603  0.000006
# ..hreading.py:249 Condition.__exit__  255    0.001061  0.001561  0.000006
# ..gloo/gl/_gl2.py:14 glActiveTexture  494    0.001551  0.001551  0.000003
# ../_asarray.py:139 ascontiguousarray  255    0.000994  0.001549  0.000006
# ..omnumeric.py:2029 _clip_dispatcher  765    0.001507  0.001507  0.000002
# ..oo/glir.py:549 GlirQueue.associate  247    0.001068  0.001502  0.000006
# ..2.py:449 glEnableVertexAttribArray  494    0.001485  0.001485  0.000003
# ..oo/buffer.py:217 VertexBuffer.size  741    0.001481  0.001481  0.000002
# ..ib/arraypad.py:524 _pad_dispatcher  765    0.001478  0.001478  0.000002
# ..loo/context.py:215 GLShared.parser  741    0.001467  0.001467  0.000002
# ..oo/context.py:147 GLContext.shared  741    0.001450  0.001450  0.000002
# ..lib/stride_tricks.py:119 <genexpr>  765    0.001442  0.001442  0.000002
# ..omnumeric.py:2584 _amax_dispatcher  766    0.001441  0.001441  0.000002
# ..ncio/events.py:79 TimerHandle._run  2      0.000015  0.001427  0.000713
# ../_internal.py:249 _ctypes.__init__  247    0.001411  0.001411  0.000006
# ..y/core/arrayprint.py:65 <dictcomp>  511    0.001361  0.001361  0.000003
# ..ofiler.py:59 DisabledProfiler.mark  741    0.001346  0.001346  0.000002
# ..yers/image/image.py:511 <listcomp>  255    0.001305  0.001305  0.000005
# ..tils.py:184 dask_optimized_slicing  510    0.001300  0.001300  0.000003
# ..oo/gl/_gl2.py:51 glBindFramebuffer  247    0.001206  0.001206  0.000005
# ..gl/_gl2.py:114 glBlendFuncSeparate  247    0.001203  0.001203  0.000005
# ../qt_dims.py:402 QtDims.enable_play  502    0.001145  0.001145  0.000002
# ..e/_image_view.py:40 ImageView.view  510    0.001133  0.001133  0.000002
# ..ge/_image_view.py:57 ImageView.raw  511    0.001109  0.001109  0.000002
# ..age.py:478 Image._raw_to_displayed  510    0.001102  0.001102  0.000002
# ..yers/base/base.py:568 Image.status  511    0.001094  0.001094  0.000002
# ..layers/base/base.py:241 Image.name  511    0.001071  0.001071  0.000002
# ../glir.py:480 _GlirQueueShare.clear  494    0.001022  0.001022  0.000002
# ..dgets/widget.py:409 Widget.picking  494    0.001010  0.001010  0.000002
# ..unctions.py:224 _nanmin_dispatcher  510    0.001005  0.001005  0.000002
# ..heck.py:363 _nan_to_num_dispatcher  510    0.000973  0.000973  0.000002
# ..ispy/gloo/program.py:503 <genexpr>  494    0.000964  0.000964  0.000002
# ..oop.py:735 ZMQIOLoop._run_callback  1      0.000009  0.000954  0.000954
# ..t.py:206 QtCustomTitleBar.sizeHint  60     0.000575  0.000947  0.000016
# ..l/iostream.py:359 OutStream._flush  1      0.000040  0.000945  0.000945
# ..visual.py:597 Widget._prepare_draw  494    0.000903  0.000903  0.000002
# .._mixin.py:63 Image.contrast_limits  255    0.000894  0.000894  0.000004
# ..yers/image/image.py:505 <listcomp>  255    0.000893  0.000893  0.000004
# ..numeric.py:194 _reshape_dispatcher  255    0.000848  0.000848  0.000003
# ..client/session.py:660 Session.send  1      0.000051  0.000829  0.000829
# ..py/core/getlimits.py:522 iinfo.max  255    0.000819  0.000819  0.000003
# ..onents/layerlist.py:209 <listcomp>  255    0.000817  0.000817  0.000003
# ../core/shape_base.py:433 <listcomp>  255    0.000793  0.000793  0.000003
# ..yers/image/image.py:510 <listcomp>  255    0.000787  0.000787  0.000003
# ..y/core/shape_base.py:425 <setcomp>  255    0.000775  0.000775  0.000003
# ..422 WeakKeyDictionary.__contains__  247    0.000769  0.000769  0.000003
# ..yers/image/image.py:506 <listcomp>  255    0.000757  0.000757  0.000003
# ..103 ModularProgram.build_if_needed  247    0.000721  0.000721  0.000003
# ..icks.py:24 _maybe_view_as_subclass  255    0.000665  0.000665  0.000003
# ..numpy/core/_dtype.py:24 _kind_name  255    0.000642  0.000642  0.000003
# ..unk/_request.py:57 ChunkKey.__eq__  255    0.000642  0.000642  0.000003
# ..ers/base/base.py:264 Image.opacity  255    0.000635  0.000635  0.000002
# ..:1435 GlirTexture2D._get_alignment  247    0.000633  0.000633  0.000003
# ..support.py:35 _extend_mode_to_code  255    0.000632  0.000632  0.000002
# ..core/_internal.py:303 _ctypes.data  247    0.000608  0.000608  0.000002
# ..onents/layerlist.py:210 <listcomp>  255    0.000595  0.000595  0.000002
# ..intensity_mixin.py:115 Image.gamma  255    0.000590  0.000590  0.000002
# ..tensity_mixin.py:46 Image.colormap  255    0.000583  0.000583  0.000002
# ..numeric.py:995 _argsort_dispatcher  255    0.000581  0.000581  0.000002
# ..:382 WeakKeyDictionary.__getitem__  247    0.000573  0.000573  0.000002
# ..spy/gloo/texture.py:315 <listcomp>  247    0.000566  0.000566  0.000002
# ..rs/base/base.py:326 Image.editable  255    0.000555  0.000555  0.000002
# ..4 _UnixSelectorEventLoop._run_once  1      0.000029  0.000553  0.000553
# ..el/iostream.py:386 OutStream.write  2      0.000072  0.000534  0.000267
# ..y/gloo/wrappers.py:63 _check_valid  247    0.000531  0.000531  0.000002
# ..stream.py:197 IOPubThread.schedule  4      0.000144  0.000517  0.000129
# ..s/base/base.py:518 Image.thumbnail  255    0.000504  0.000504  0.000002
# ..lobject.py:106 ModularProgram.glir  247    0.000500  0.000500  0.000002
# ..e/base.py:721 Image._set_highlight  255    0.000494  0.000494  0.000002
# ..meric.py:197 _ones_like_dispatcher  255    0.000493  0.000493  0.000002
# ..unctions.py:339 _nanmax_dispatcher  255    0.000487  0.000487  0.000002
# ..t/session.py:601 Session.serialize  1      0.000043  0.000486  0.000486
# ..ks.py:137 _broadcast_to_dispatcher  255    0.000478  0.000478  0.000002
# ..y/core/multiarray.py:75 empty_like  255    0.000472  0.000472  0.000002
# ../scene/visuals.py:55 Image.picking  247    0.000458  0.000458  0.000002
# ..io.py:137 ZMQIOLoop._handle_events  1      0.000008  0.000441  0.000441
# ..am.py:446 ZMQStream._handle_events  1      0.000026  0.000433  0.000433
# ..mq/sugar/socket.py:342 Socket.send  11     0.000300  0.000300  0.000027
# ..yter_client/session.py:81 <lambda>  4      0.000021  0.000282  0.000070
# ..ages/zmq/utils/jsonapi.py:31 dumps  4      0.000040  0.000261  0.000065
# ..ream.py:471 ZMQStream._handle_recv  1      0.000013  0.000255  0.000255
# ..eam.py:432 ZMQStream._run_callback  1      0.000009  0.000233  0.000233
# ..m.py:107 IOPubThread._handle_event  1      0.000009  0.000224  0.000224
# ..ipykernel/iostream.py:214 <lambda>  1      0.000009  0.000209  0.000209
# ..thon3.8/json/__init__.py:183 dumps  4      0.000039  0.000206  0.000051
# ..am.py:216 IOPubThread._really_send  1      0.000012  0.000200  0.000200
# ..ocket.py:402 Socket.send_multipart  1      0.000043  0.000171  0.000171
# ../encoder.py:182 JSONEncoder.encode  4      0.000042  0.000156  0.000039
# ../threading.py:1071 Thread.is_alive  4      0.000077  0.000147  0.000037
# ..model.py:384 Viewer._update_status  1      0.000006  0.000141  0.000141
# ../viewer_model.py:158 Viewer.status  1      0.000010  0.000135  0.000135
# ..client/session.py:586 Session.sign  1      0.000029  0.000125  0.000125
# ...py:209 IOPubThread.send_multipart  1      0.000006  0.000114  0.000114
# .._client/session.py:567 Session.msg  1      0.000016  0.000111  0.000111
# ..py:511 ZMQStream._rebuild_io_state  1      0.000021  0.000109  0.000109
# ..m.py:323 OutStream._schedule_flush  2      0.000015  0.000092  0.000046
# ../traitlets.py:564 CUnicode.__get__  15     0.000059  0.000091  0.000006
# ..oder.py:204 JSONEncoder.iterencode  4      0.000035  0.000090  0.000022
# ../session.py:564 Session.msg_header  1      0.000013  0.000079  0.000079
# ..attrsettr.py:38 Socket.__getattr__  2      0.000028  0.000076  0.000038
# ..6 ModifiedScrollBar.mouseMoveEvent  1      0.000037  0.000058  0.000058
# ..client/jsonutil.py:84 date_default  2      0.000021  0.000055  0.000027
# ..:1017 Thread._wait_for_tstate_lock  4      0.000036  0.000054  0.000013
# ..tlets/traitlets.py:595 Int.__set__  1      0.000006  0.000052  0.000052
# ..traitlets/traitlets.py:577 Int.set  1      0.000008  0.000046  0.000046
# ..m.py:534 ZMQStream._update_handler  1      0.000008  0.000044  0.000044
# ..zmqstream.py:425 ZMQStream.sending  1      0.000009  0.000042  0.000042
# ..trsettr.py:50 Socket._get_attr_opt  2      0.000038  0.000038  0.000019
# ..ets/traitlets.py:606 Int._validate  1      0.000014  0.000038  0.000038
# ..ctors.py:553 KqueueSelector.select  1      0.000017  0.000035  0.000035
# ../python3.8/queue.py:96 Queue.empty  1      0.000024  0.000033  0.000033
# ..lets/traitlets.py:533 CUnicode.get  15     0.000032  0.000032  0.000002
# ..y:310 OutStream._is_master_process  2      0.000022  0.000030  0.000015
# ..r_client/session.py:217 msg_header  1      0.000007  0.000030  0.000030
# ..r_client/session.py:742 <listcomp>  1      0.000015  0.000027  0.000027
# ..thon3.8/hmac.py:130 HMAC.hexdigest  1      0.000007  0.000027  0.000027
# ..b/python3.8/hmac.py:94 HMAC.update  4      0.000015  0.000026  0.000006
# ..ndow.py:468 Window._status_changed  1      0.000008  0.000024  0.000024
# ..xSelectorEventLoop._process_events  2      0.000009  0.000024  0.000012
# ..lib/python3.8/hmac.py:98 HMAC.copy  1      0.000013  0.000024  0.000024
# ..ient/session.py:511 Session.msg_id  1      0.000012  0.000024  0.000024
# ..eam.py:426 OutStream._flush_buffer  1      0.000013  0.000022  0.000022
# ..pyter_client/session.py:148 utcnow  1      0.000010  0.000020  0.000020
# ..ore.py:497 MagicGui.current_kwargs  1      0.000013  0.000018  0.000018
# ..ream.py:93 IOPubThread._event_pipe  4      0.000018  0.000018  0.000004
# ...py:164 IOPubThread._check_mp_mode  1      0.000011  0.000017  0.000017
# ..ython3.8/hmac.py:111 HMAC._current  1      0.000009  0.000017  0.000017
# ..n3.8/threading.py:513 Event.is_set  4      0.000016  0.000016  0.000004
# ..py:662 _UnixSelectorEventLoop.time  2      0.000011  0.000015  0.000007
# ..nixSelectorEventLoop._add_callback  1      0.000009  0.000015  0.000015
# ..ets/traitlets.py:2037 Int.validate  1      0.000008  0.000013  0.000013
# ..ncoder.py:104 JSONEncoder.__init__  4      0.000011  0.000011  0.000003
# ..ython3.8/queue.py:208 Queue._qsize  1      0.000006  0.000009  0.000009
# ..ocket.py:449 Socket.recv_multipart  1      0.000009  0.000009  0.000009
# ..aitlets.py:615 Int._cross_validate  1      0.000005  0.000008  0.000008
# ..on_genutils/py3compat.py:19 encode  1      0.000006  0.000008  0.000008
# ..ient/session.py:223 extract_header  1      0.000005  0.000007  0.000007
# ..161 IOPubThread._is_master_process  1      0.000004  0.000006  0.000006
# ..ient/jsonutil.py:31 _ensure_tzinfo  2      0.000006  0.000006  0.000003
# ../viewer_model.py:152 Viewer.status  1      0.000005  0.000005  0.000005
# ..es/magicgui/core.py:500 <dictcomp>  1      0.000005  0.000005  0.000005
# ..qstream.py:421 ZMQStream.receiving  2      0.000005  0.000005  0.000002
# ..es/magicgui/core.py:528 <dictcomp>  1      0.000004  0.000004  0.000004
# ..tream.py:439 OutStream._new_buffer  1      0.000004  0.000004  0.000004
# ..traitlets.py:2001 _validate_bounds  1      0.000003  0.000003  0.000003
# ..teutil/tz/tz.py:74 tzutc.utcoffset  1      0.000003  0.000003  0.000003
# ..py:275 KqueueSelector._key_from_fd  1      0.000003  0.000003  0.000003
# ..ages/magicgui/core.py:199 <lambda>  1      0.000000  0.000000  0.000000
# ..input-11-b1e20c0f3ba4>:18 stop_acq  1      0.000000  0.000000  0.000000
# ..cgui/core.py:502 MagicGui.__call__  1      0.000000  0.000000  0.000000
# Function stats for (N/A) (1)
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# SystemError: NULL object passed to Py_BuildValue
# Function stats for (ParentPollerUnix) (3)
# Function stats for (Thread) (2)
#
# Clock type: CPU
# Ordered by: totaltime, desc
#
# name                                  ncall  tsub      ttot      tavg
# ..ncio/events.py:79 TimerHandle._run  2      0.000015  0.001427  0.000713
# ..oop.py:735 ZMQIOLoop._run_callback  1      0.000009  0.000954  0.000954
# ..l/iostream.py:359 OutStream._flush  1      0.000040  0.000945  0.000945
# ..client/session.py:660 Session.send  1      0.000051  0.000829  0.000829
# ..4 _UnixSelectorEventLoop._run_once  1      0.000029  0.000553  0.000553
# ..t/session.py:601 Session.serialize  1      0.000043  0.000486  0.000486
# ..io.py:137 ZMQIOLoop._handle_events  1      0.000008  0.000441  0.000441
# ..am.py:446 ZMQStream._handle_events  1      0.000026  0.000433  0.000433
# ..yter_client/session.py:81 <lambda>  4      0.000021  0.000282  0.000070
# ..ages/zmq/utils/jsonapi.py:31 dumps  4      0.000040  0.000261  0.000065
# ..ream.py:471 ZMQStream._handle_recv  1      0.000013  0.000255  0.000255
# ..eam.py:432 ZMQStream._run_callback  1      0.000009  0.000233  0.000233
# ..m.py:107 IOPubThread._handle_event  1      0.000009  0.000224  0.000224
# ..ipykernel/iostream.py:214 <lambda>  1      0.000009  0.000209  0.000209
# ..thon3.8/json/__init__.py:183 dumps  4      0.000039  0.000206  0.000051
# ..am.py:216 IOPubThread._really_send  1      0.000012  0.000200  0.000200
# ..mq/sugar/socket.py:342 Socket.send  8      0.000174  0.000174  0.000022
# ..ocket.py:402 Socket.send_multipart  1      0.000043  0.000171  0.000171
# ../encoder.py:182 JSONEncoder.encode  4      0.000042  0.000156  0.000039
# ..client/session.py:586 Session.sign  1      0.000029  0.000125  0.000125
# ...py:209 IOPubThread.send_multipart  1      0.000006  0.000114  0.000114
# .._client/session.py:567 Session.msg  1      0.000016  0.000111  0.000111
# ..py:511 ZMQStream._rebuild_io_state  1      0.000021  0.000109  0.000109
# ..stream.py:197 IOPubThread.schedule  1      0.000024  0.000108  0.000108
# ../traitlets.py:564 CUnicode.__get__  15     0.000059  0.000091  0.000006
# ..oder.py:204 JSONEncoder.iterencode  4      0.000035  0.000090  0.000022
# ../session.py:564 Session.msg_header  1      0.000013  0.000079  0.000079
# ..attrsettr.py:38 Socket.__getattr__  2      0.000028  0.000076  0.000038
# ..client/jsonutil.py:84 date_default  2      0.000021  0.000055  0.000027
# ..tlets/traitlets.py:595 Int.__set__  1      0.000006  0.000052  0.000052
# ..traitlets/traitlets.py:577 Int.set  1      0.000008  0.000046  0.000046
# ..m.py:534 ZMQStream._update_handler  1      0.000008  0.000044  0.000044
# ..zmqstream.py:425 ZMQStream.sending  1      0.000009  0.000042  0.000042
# ..trsettr.py:50 Socket._get_attr_opt  2      0.000038  0.000038  0.000019
# ..ets/traitlets.py:606 Int._validate  1      0.000014  0.000038  0.000038
# ..ctors.py:553 KqueueSelector.select  1      0.000017  0.000035  0.000035
# ../python3.8/queue.py:96 Queue.empty  1      0.000024  0.000033  0.000033
# ..lets/traitlets.py:533 CUnicode.get  15     0.000032  0.000032  0.000002
# ..r_client/session.py:217 msg_header  1      0.000007  0.000030  0.000030
# ..r_client/session.py:742 <listcomp>  1      0.000015  0.000027  0.000027
# ..thon3.8/hmac.py:130 HMAC.hexdigest  1      0.000007  0.000027  0.000027
# ..b/python3.8/hmac.py:94 HMAC.update  4      0.000015  0.000026  0.000006
# ..xSelectorEventLoop._process_events  2      0.000009  0.000024  0.000012
# ..lib/python3.8/hmac.py:98 HMAC.copy  1      0.000013  0.000024  0.000024
# ..ient/session.py:511 Session.msg_id  1      0.000012  0.000024  0.000024
# ..eam.py:426 OutStream._flush_buffer  1      0.000013  0.000022  0.000022
# ../threading.py:1071 Thread.is_alive  1      0.000011  0.000021  0.000021
# ..pyter_client/session.py:148 utcnow  1      0.000010  0.000020  0.000020
# ...py:164 IOPubThread._check_mp_mode  1      0.000011  0.000017  0.000017
# ..ython3.8/hmac.py:111 HMAC._current  1      0.000009  0.000017  0.000017
# ..py:662 _UnixSelectorEventLoop.time  2      0.000011  0.000015  0.000007
# ..nixSelectorEventLoop._add_callback  1      0.000009  0.000015  0.000015
# ..ets/traitlets.py:2037 Int.validate  1      0.000008  0.000013  0.000013
# ..ncoder.py:104 JSONEncoder.__init__  4      0.000011  0.000011  0.000003
# ..ython3.8/queue.py:208 Queue._qsize  1      0.000006  0.000009  0.000009
# ..ocket.py:449 Socket.recv_multipart  1      0.000009  0.000009  0.000009
# ..:1017 Thread._wait_for_tstate_lock  1      0.000006  0.000008  0.000008
# ..aitlets.py:615 Int._cross_validate  1      0.000005  0.000008  0.000008
# ..on_genutils/py3compat.py:19 encode  1      0.000006  0.000008  0.000008
# ..ient/session.py:223 extract_header  1      0.000005  0.000007  0.000007
# ..161 IOPubThread._is_master_process  1      0.000004  0.000006  0.000006
# ..ient/jsonutil.py:31 _ensure_tzinfo  2      0.000006  0.000006  0.000003
# ..qstream.py:421 ZMQStream.receiving  2      0.000005  0.000005  0.000002
# ..tream.py:439 OutStream._new_buffer  1      0.000004  0.000004  0.000004
# ..traitlets.py:2001 _validate_bounds  1      0.000003  0.000003  0.000003
# ..teutil/tz/tz.py:74 tzutc.utcoffset  1      0.000003  0.000003  0.000003
# ..py:275 KqueueSelector._key_from_fd  1      0.000003  0.000003  0.000003
# ..ream.py:93 IOPubThread._event_pipe  1      0.000003  0.000003  0.000003
# ..n3.8/threading.py:513 Event.is_set  1      0.000002  0.000002  0.000002
